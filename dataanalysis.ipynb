# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/Users/naoki/G2-DSprogramming/脈拍数 - フォームの回答 1.csv')

# %%
df
# Out:
#        測った時の日付   今の時間帯 計測値(その１) 計測地(地名）\noo区やoo市だけで大丈夫です！  \
# 0   2024/01/12    6~7時      埼玉県                       久喜市
# 1   2024/01/12    8~9時      埼玉県                       久喜市
# 2   2024/01/12   9~10時      埼玉県                       久喜市
# 3   2024/01/12  11~12時      埼玉県                       久喜市
# 4   2024/01/12  12~13時      埼玉県                       久喜市
# 5   2024/01/12  13~14時      埼玉県                       久喜市
# 6   2024/01/12  14~15時      埼玉県                       久喜市
# 7   2024/01/12  18~19時      埼玉県                       久喜市
# 8   2024/01/12  19~20時      埼玉県                       久喜市
# 9   2024/01/12  20~21時      埼玉県                       久喜市
# 10  2024/01/12  21~22時      埼玉県                       久喜市
# 11  2024/01/12  22~23時      埼玉県                       久喜市
# 12  2024/01/12  23~24時      埼玉県                       久喜市
# 13  2024/01/13  13~14時      埼玉県                       久喜市
# 14  2024/01/13    6~7時      埼玉県                       久喜市
# ...

# %%
#てsy
