# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/Users/naoki/G2-DSprogramming/G2-DSprogramming/脈拍数 - フォームの回答 1.csv')

# %%
df
# Out:
#        測った時の日付   今の時間帯 計測値(その１) 計測地(地名）\noo区やoo市だけで大丈夫です！  脈拍
# 0   2024/01/12    6~7時      埼玉県                       久喜市  72
# 1   2024/01/12    8~9時      埼玉県                       久喜市  72
# 2   2024/01/12   9~10時      埼玉県                       久喜市  69
# 3   2024/01/12  11~12時      埼玉県                       久喜市  72
# 4   2024/01/12  12~13時      埼玉県                       久喜市  66
# 5   2024/01/12  13~14時      埼玉県                       久喜市  72
# 6   2024/01/12  14~15時      埼玉県                       久喜市  69
# 7   2024/01/12  18~19時      埼玉県                       久喜市  66
# 8   2024/01/12  19~20時      埼玉県                       久喜市  72
# 9   2024/01/12  20~21時      埼玉県                       久喜市  69
# 10  2024/01/12  21~22時      埼玉県                       久喜市  63
# 11  2024/01/12  22~23時      埼玉県                       久喜市  69
# 12  2024/01/12  23~24時      埼玉県                       久喜市  63
# 13  2024/01/13  13~14時      埼玉県                       久喜市  69
# ...

# %%
df.iloc[:,4]
# Out:
# 0     72
# 1     72
# 2     69
# 3     72
# 4     66
# 5     72
# 6     69
# 7     66
# 8     72
# 9     69
# 10    63
# 11    69
# 12    63
# 13    69
# 14    63
# 15    72
# 16    66
# 17    96
# 18    75
# 19    78
# 20    75
# 21    84
# 22    63
# 23    59
# 24    75
# 25    69
# 26    69
# 27    66
# 28    72
# Name: 脈拍, dtype: int64

# %%
pulse_data = {'気温':[-4.5,-2.1,0.4,7.1,10.1,11.4,13.6,6.0,4.5,7.7,6.4,3.7,3.2,10.3,-0.3,5.9,9.8,2.0,1.2,-0.2,-3.1,5.5,1.2,-0.5,0.2,7.7,8.8,9.7,9.8],'脈拍数':[72,72,69,72,66,72,69,66,72,69,63,69,63,69,63,72,66,96,75,78,75,84,63,59,75,69,69,66,72]}

pulse_df = pd.DataFrame(pulse_data)
pulse_df
# Out:
#       気温  脈拍数
# 0   -4.5   72
# 1   -2.1   72
# 2    0.4   69
# 3    7.1   72
# 4   10.1   66
# 5   11.4   72
# 6   13.6   69
# 7    6.0   66
# 8    4.5   72
# 9    7.7   69
# 10   6.4   63
# 11   3.7   69
# 12   3.2   63
# 13  10.3   69
# 14  -0.3   63
# 15   5.9   72
# 16   9.8   66
# 17   2.0   96
# 18   1.2   75
# 19  -0.2   78
# 20  -3.1   75
# 21   5.5   84
# 22   1.2   63
# 23  -0.5   59
# 24   0.2   75
# 25   7.7   69
# 26   8.8   69
# 27   9.7   66
# 28   9.8   72

# %%
pulse_df.plot.box(showmeans=True) # 箱ひげ図表示
# Out:
# <Axes: >
# /Users/naoki/Library/Python/3.9/lib/python/site-packages/IPython/core/events.py:93: UserWarning: Glyph 27671 (\N{CJK UNIFIED IDEOGRAPH-6C17}) missing from current font.
#   func(*args, **kwargs)
# /Users/naoki/Library/Python/3.9/lib/python/site-packages/IPython/core/events.py:93: UserWarning: Glyph 28201 (\N{CJK UNIFIED IDEOGRAPH-6E29}) missing from current font.
#   func(*args, **kwargs)
# /Users/naoki/Library/Python/3.9/lib/python/site-packages/IPython/core/events.py:93: UserWarning: Glyph 33032 (\N{CJK UNIFIED IDEOGRAPH-8108}) missing from current font.
#   func(*args, **kwargs)
# /Users/naoki/Library/Python/3.9/lib/python/site-packages/IPython/core/events.py:93: UserWarning: Glyph 25293 (\N{CJK UNIFIED IDEOGRAPH-62CD}) missing from current font.
#   func(*args, **kwargs)
# /Users/naoki/Library/Python/3.9/lib/python/site-packages/IPython/core/events.py:93: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
pulse_df.corr()
# Out:
#           気温      脈拍数
# 気温   1.00000 -0.15569
# 脈拍数 -0.15569  1.00000

# %%
import seaborn as sns
sns.heatmap(pulse_df.corr(), cmap='summer')
# Out:
# /Users/naoki/Library/Python/3.9/lib/python/site-packages/seaborn/utils.py:80: UserWarning: Glyph 27671 (\N{CJK UNIFIED IDEOGRAPH-6C17}) missing from current font.
#   fig.canvas.draw()
# /Users/naoki/Library/Python/3.9/lib/python/site-packages/seaborn/utils.py:80: UserWarning: Glyph 28201 (\N{CJK UNIFIED IDEOGRAPH-6E29}) missing from current font.
#   fig.canvas.draw()
# /Users/naoki/Library/Python/3.9/lib/python/site-packages/seaborn/utils.py:80: UserWarning: Glyph 33032 (\N{CJK UNIFIED IDEOGRAPH-8108}) missing from current font.
#   fig.canvas.draw()
# /Users/naoki/Library/Python/3.9/lib/python/site-packages/seaborn/utils.py:80: UserWarning: Glyph 25293 (\N{CJK UNIFIED IDEOGRAPH-62CD}) missing from current font.
#   fig.canvas.draw()
# /Users/naoki/Library/Python/3.9/lib/python/site-packages/seaborn/utils.py:80: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   fig.canvas.draw()
# <Axes: >
# ...
